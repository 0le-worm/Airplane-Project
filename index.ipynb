# %% [markdown]
# ##EXPLORATION DRAFT##

# %% [markdown]
# This is the Branch we will parse the data in. You can load the data below.

# %% [markdown]
# Business Understanding

# %% [markdown]
# we are a medium size company. we want to purchase an safest airplane on a budget.
# we have a budget of $12 million. according to research, singele engine and reciprocating engine type is the safest yet the cheapest.
# however, we wsnt the lowest ricke of airlane. we recommend to uprgrade to turbo 1 engine or 2 engine number within a budget.
# these are the makes we found safest within 1engine or 2 engine number.

# %% [markdown]
# Data Understanding

# %%
#importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pulling csv file
state = pd.read_csv('./airplane_data/USState_Codes.csv')

aviation_2008 = pd.read_csv('./airplane_data/AviationData.csv', encoding='latin-1')
# Out:
# /Users/goknurkaya/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Filter data for years 2008 and later
aviation["Year"] = aviation["Event.Date"].map(lambda x: int(x[:4]))
aviation["Year"] = aviation["Year"].astype(int)
aviation_2008 = aviation[aviation["Year"] >= 2008]

# Filter for 'Aircraft.Category' == 'Airplane'
aviation_2008 = aviation_2008[aviation_2008["Aircraft.Category"] == "Airplane"]

# Drop rows with missing values in 'Number.of.Engines' and 'Engine.Type'
aviation_2008 = aviation_2008.dropna(subset=["Number.of.Engines", "Engine.Type"])

# Filter for 'Amateur.Built' == 'No' 
aviation_2008 = aviation_2008[aviation_2008['Amateur.Built'] == 'No']

# %%
# Investigating frequency of accidents/incidents by year
years = aviation_2008["Year"].value_counts().sort_index().index
fre_years = aviation_2008["Year"].value_counts().sort_index().values

# Plotting
fig, ax = plt.subplots( figsize = (10, 5))
ax.bar(years, fre_years)
ax.set_xticklabels(years, rotation = 90)
ax.set_ylabel("Number of accidents/incidents")
ax.set_xlabel("Years")
ax.set_title("Number of accidents/incidents by year");
# Out:
# <ipython-input-187-cb62edd4ad00>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(years, rotation = 90)

# %%
# Investigating frequency of accidents/incidents by year
years = aviation_2008["Year"].value_counts().sort_index().index
fre_years = aviation_2008["Year"].value_counts().sort_index().values

# Plotting
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(years, fre_years)
ax.set_xticklabels(years, rotation=90)
ax.set_ylabel("Number of accidents/incidents")
ax.set_xlabel("Years")
ax.set_title("Number of accidents/incidents by year");
# Out:
# <ipython-input-188-20e09556fa4e>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(years, rotation=90)

# %%
# Investigating fatality by year 
aviation_2008['Total_Injuries'] = aviation_2008['Total.Fatal.Injuries'] + aviation_2008['Total.Serious.Injuries']
a_year = aviation_2008.groupby("Year")["Total_Injuries"].sum().index

fatality = aviation_2008.groupby("Year")["Total_Injuries"].sum().values

# Plotting
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(a_year, fatality)
ax.set_xticklabels(a_year, rotation=90)
ax.set_ylabel("Number of fatalities")
ax.set_xlabel("Years")
ax.set_title("Number of fatalities by year");
# Out:
# <ipython-input-189-a2067ecdb4b1>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(a_year, rotation=90)

# %%
# Percentage of Accidents/Incidents by Number of Engines
aviation_2008["Number.of.Engines"].value_counts(normalize = True)
# Out:
# 1.0    0.843972
# 2.0    0.151348
# 4.0    0.003475
# 3.0    0.001064
# 8.0    0.000071
# 0.0    0.000071
# Name: Number.of.Engines, dtype: float64

# %%
# Percentage of Accidents/Incidents by Engine Type
aviation_2008["Engine.Type"].value_counts(normalize = True)
# Out:
# Reciprocating      0.864043
# Turbo Prop         0.072908
# Turbo Fan          0.052482
# Turbo Jet          0.007730
# Unknown            0.001206
# Geared Turbofan    0.000780
# Turbo Shaft        0.000426
# Electric           0.000355
# UNK                0.000071
# Name: Engine.Type, dtype: float64

# %%
df_engine = aviation_2008[aviation_2008["Number.of.Engines"] > 1]
df_engine["Number.of.Engines"].value_counts(normalize = True)
# Out:
# 2.0    0.970441
# 4.0    0.022283
# 3.0    0.006821
# 8.0    0.000455
# Name: Number.of.Engines, dtype: float64

# %%
# Want to see engine number based on year 
# Pivot the DataFrame to have each unique number_of_engines as a separate column
pivot_df = aviation_2008.pivot_table(index='Year', columns='Number.of.Engines', aggfunc='size', fill_value=0)

# Create a line plot for each column
plt.figure(figsize=(10, 6))
for column in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[column], label=f'{column} Engines')

plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Number of Engines Over the Years')
plt.legend(title='Number of Engines', loc='upper left')
plt.grid(True)
plt.xticks(rotation = 90)

# Show the plot
plt.show()

# %%
# Want to see engine type based on year 
# Pivot the DataFrame to have each unique number_of_engines as a separate column
pivot_df1 = aviation_2008.pivot_table(index='Year', columns='Engine.Type', aggfunc='size', fill_value=0)

# Create a line plot for each column
plt.figure(figsize=(10, 6))
for column in pivot_df1.columns:
    plt.plot(pivot_df1.index, pivot_df1[column], label=f'{column}')

plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Types of Engines Over the Years')
plt.legend(title='Types of Engines', loc='upper left')
plt.grid(True)
plt.xticks(rotation = 90)

# Show the plot
plt.show()

# %%
aviation_2008['Purpose.of.flight'].value_counts()
# Out:
# Personal                     8647
# Instructional                2000
# Aerial Application            656
# Business                      341
# Positioning                   240
# Aerial Observation            128
# Other Work Use                110
# Flight Test                   103
# Skydiving                      99
# Unknown                        87
# Ferry                          80
# Executive/corporate            73
# Banner Tow                     69
# Public Aircraft - Federal      43
# Air Race show                  38
# Glider Tow                     28
# Public Aircraft - State        21
# Public Aircraft                20
# Public Aircraft - Local        12
# Firefighting                   11
# Air Drop                        3
# PUBS                            2
# ASHO                            1
# Name: Purpose.of.flight, dtype: int64

# %%
aviation_2008['Number.of.Engines'].value_counts()
# Out:
# 1.0    11900
# 2.0     2134
# 4.0       49
# 3.0       15
# 8.0        1
# 0.0        1
# Name: Number.of.Engines, dtype: int64

# %%
missing_values = aviation_2008.isna().sum()
missing_values
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                      0
# Country                       0
# Latitude                    318
# Longitude                   318
# Airport.Code               3819
# Airport.Name               3650
# Injury.Severity             140
# Aircraft.damage             443
# Aircraft.Category             0
# Registration.Number           0
# Make                          0
# Model                         2
# Amateur.Built                 0
# Number.of.Engines             0
# Engine.Type                   0
# FAR.Description              94
# Schedule                  12867
# Purpose.of.flight          1288
# Air.carrier                6067
# Total.Fatal.Injuries          0
# Total.Serious.Injuries        0
# Total.Minor.Injuries          0
# Total.Uninjured               0
# Weather.Condition           552
# Broad.phase.of.flight     14100
# Report.Status               974
# Publication.Date             18
# Year                          0
# Total_Injuries                0
# dtype: int64

# %%
summary_statistics = aviation_2008[['Total.Fatal.Injuries', 'Total.Serious.Injuries']].describe()

print(summary_statistics)
# Out:
#        Total.Fatal.Injuries  Total.Serious.Injuries
# count          14100.000000            14100.000000
# mean               0.338298                0.294326
# std                1.712268                2.017136
# min                0.000000                0.000000
# 25%                0.000000                0.000000
# 50%                0.000000                0.000000
# 75%                0.000000                0.000000
# max              157.000000              137.000000

# %%
aviation_2008['Engine.Type'].value_counts()
# Out:
# Reciprocating      12183
# Turbo Prop          1028
# Turbo Fan            740
# Turbo Jet            109
# Unknown               17
# Geared Turbofan       11
# Turbo Shaft            6
# Electric               5
# UNK                    1
# Name: Engine.Type, dtype: int64

# %%
aviation_2008['Purpose.of.flight'].value_counts(normalize=True)
# Out:
# Personal                     0.674914
# Instructional                0.156104
# Aerial Application           0.051202
# Business                     0.026616
# Positioning                  0.018732
# Aerial Observation           0.009991
# Other Work Use               0.008586
# Flight Test                  0.008039
# Skydiving                    0.007727
# Unknown                      0.006791
# Ferry                        0.006244
# Executive/corporate          0.005698
# Banner Tow                   0.005386
# Public Aircraft - Federal    0.003356
# Air Race show                0.002966
# Glider Tow                   0.002185
# Public Aircraft - State      0.001639
# Public Aircraft              0.001561
# Public Aircraft - Local      0.000937
# Firefighting                 0.000859
# Air Drop                     0.000234
# PUBS                         0.000156
# ASHO                         0.000078
# Name: Purpose.of.flight, dtype: float64

# %%
aviation_2008['Number.of.Engines'].value_counts()
# Out:
# 1.0    11900
# 2.0     2134
# 4.0       49
# 3.0       15
# 8.0        1
# 0.0        1
# Name: Number.of.Engines, dtype: int64

# %%
df = aviation_2008[['Make', 'Number.of.Engines', 'Engine.Type', 'Total.Fatal.Injuries', 'Total.Serious.Injuries']].copy()

df[['Total.Fatal.Injuries', 'Total.Serious.Injuries']] = df[['Total.Fatal.Injuries', 'Total.Serious.Injuries']].fillna(0)

df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']

result = df.groupby(['Make'])[['Number.of.Engines', 'Engine.Type', 'Total_Injuries']].max()
result = result.reset_index()

#sorted_result = result.sort_values(by='Total_Injuries', ascending=False)

#print(sorted_result.head(20))

# %%
sorted_result = result.sort_values(by='Total_Injuries', ascending=False)

sorted_result.head(20)
# Out:
#                      Make  Number.of.Engines  Engine.Type  Total_Injuries
# 32                 AIRBUS                4.0    Turbo Fan           157.0
# 142                BOEING                4.0      Unknown           140.0
# 148        BOMBARDIER INC                2.0   Turbo Prop            49.0
# 846                SUKHOI                2.0    Turbo Fan            44.0
# 344               EMBRAER                2.0   Turbo Prop            28.0
# 143        BOEING COMPANY                2.0    Turbo Fan            19.0
# 119          Aviocar CASA                2.0   Turbo Prop            18.0
# 691               PILATUS                1.0   Turbo Prop            14.0
# 198                CESSNA                2.0      Unknown            12.0
# 455  GULFSTREAM AEROSPACE                2.0    Turbo Jet            12.0
# 694                 PIPER                2.0      Unknown            11.0
# 172                 Beech                2.0   Turbo Prop            11.0
# 307           DEHAVILLAND                2.0  Turbo Shaft            10.0
# 134                 BEECH                2.0      Unknown            10.0
# 366      Embraer Aircraft                2.0   Turbo Prop            10.0
# 903      Textron Aviation                2.0   Turbo Prop            10.0
# 154     BRITISH AEROSPACE                4.0   Turbo Prop             9.0
# 454            GULFSTREAM                2.0    Turbo Fan             9.0
# 427   GATES LEARJET CORP.                2.0    Turbo Fan             9.0
# 95                 Airbus                2.0    Turbo Fan             9.0

# %%
sorted_result.tail(20)
# Out:
#                               Make  Number.of.Engines    Engine.Type  \
# 581                          Leigh                1.0  Reciprocating
# 557                      L GOLDNER                1.0  Reciprocating
# 554                     Kitty Hawk                8.0       Electric
# 528                         JABIRU                1.0  Reciprocating
# 542                     KELM DAVID                1.0  Reciprocating
# 530  JABIRU USA SPORT AIRCRAFT LLC                1.0  Reciprocating
# 535                    JOHN Sample                1.0  Reciprocating
# 537              JUST AIRCRAFT LLC                1.0  Reciprocating
# 538                        Jackson                1.0  Reciprocating
# 144     BOEING OF CANADA/DEHAV DIV                2.0     Turbo Prop
# 541              KAKELDEY RONALD O                1.0  Reciprocating
# 543                KENNETH M FRANZ                1.0  Reciprocating
# 552          Keuthan Aircraft Corp                1.0  Reciprocating
# 544              KESSINGER ROGER L                1.0  Reciprocating
# 546                         KINNER                1.0  Reciprocating
# 547                         KITFOX                1.0  Reciprocating
# 549               KOLB AIRCRAFT CO                1.0  Reciprocating
# 550              KOLB AIRCRAFT INC                1.0  Reciprocating
# 141                           BIRD                1.0  Reciprocating
# 491                         HEMMER                1.0  Reciprocating
#
#      Total_Injuries
# 581             0.0
# 557             0.0
# 554             0.0
# 528             0.0
# 542             0.0
# 530             0.0
# 535             0.0
# 537             0.0
# 538             0.0
# 144             0.0
# 541             0.0
# 543             0.0
# 552             0.0
# 544             0.0
# 546             0.0
# 547             0.0
# 549             0.0
# 550             0.0
# 141             0.0
# 491             0.0

# %%
df.plot(x='Number.of.Engines', y='Total_Injuries', kind='scatter');

# %%
def process_purpose(purpose):
    df = aviation_2008[aviation_2008['Purpose.of.flight'] == purpose]

    df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']

    # Group by relevant columns and aggregate
    #total = df.groupby(['Make', 'Model', 'Engine.Type']).agg({'Total_Injuries': 'sum', 'Number.of.Engines': 'max'}).reset_index()
    total = df.groupby(['Make','Engine.Type']).agg({'Total_Injuries': 'sum', 'Number.of.Engines': 'max'}).reset_index()
    total = total.sort_values(by='Total_Injuries', ascending=False)
    
    return total

# %%
process_purpose('Personal').head(50)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                             Make    Engine.Type  Total_Injuries  \
# 133                       CESSNA  Reciprocating          1278.0
# 509                        PIPER  Reciprocating           944.0
# 94                         BEECH  Reciprocating           415.0
# 187                       Cessna  Reciprocating           251.0
# 531                        Piper  Reciprocating           177.0
# 452                       MOONEY  Reciprocating           136.0
# 153           CIRRUS DESIGN CORP  Reciprocating           122.0
# 118                        Beech  Reciprocating            70.0
# 98                      BELLANCA  Reciprocating            43.0
# 95                         BEECH     Turbo Prop            42.0
# 423                     LUSCOMBE  Reciprocating            37.0
# 464                       Mooney  Reciprocating            37.0
# 11                       AERONCA  Reciprocating            35.0
# 638                      STINSON  Reciprocating            32.0
# 481               NORTH AMERICAN  Reciprocating            31.0
# 437                        MAULE  Reciprocating            30.0
# 568    RAYTHEON AIRCRAFT COMPANY  Reciprocating            30.0
# 134                       CESSNA      Turbo Fan            26.0
# 147                     CHAMPION  Reciprocating            26.0
# 631                       SOCATA     Turbo Prop            26.0
# 335  GRUMMAN AMERICAN AVN. CORP.  Reciprocating            25.0
# 510                        PIPER     Turbo Prop            24.0
# 196                       Cirrus  Reciprocating            24.0
# 3                 AERO COMMANDER  Reciprocating            23.0
# 152                       CIRRUS  Reciprocating            23.0
# 102                       BOEING  Reciprocating            20.0
# 659                  TAYLORCRAFT  Reciprocating            19.0
# 507                      PILATUS     Turbo Prop            18.0
# 451                   MITSUBISHI     Turbo Prop            17.0
# 630                       SOCATA  Reciprocating            17.0
# 267                      ERCOUPE  Reciprocating            16.0
# 136                       CESSNA     Turbo Prop            15.0
# 532                        Piper     Turbo Prop            15.0
# 301           FLIGHT DESIGN GMBH  Reciprocating            13.0
# 337                   GULFSTREAM      Turbo Fan            12.0
# 193                     Champion  Reciprocating            12.0
# 338         GULFSTREAM AEROSPACE      Turbo Fan            12.0
# 35    AMERICAN CHAMPION AIRCRAFT  Reciprocating            12.0
# 50            AVIAT AIRCRAFT INC  Reciprocating            11.0
# 263                      EMBRAER  Reciprocating            11.0
# 470                       NAVION  Reciprocating            11.0
# 550                  QUICKSILVER  Reciprocating            10.0
# 240     DIAMOND AIRCRAFT IND INC  Reciprocating            10.0
# 681             Textron Aviation     Turbo Prop            10.0
# 73             American Aviation  Reciprocating            10.0
# 529                      Pilatus     Turbo Prop            10.0
# 562                         RANS  Reciprocating             9.0
# 490               North American  Reciprocating             9.0
# 586                         RYAN  Reciprocating             9.0
# 138              CESSNA AIRCRAFT  Reciprocating             9.0
#
#      Number.of.Engines
# 133                2.0
# 509                2.0
# 94                 2.0
# 187                2.0
# 531                2.0
# 452                1.0
# 153                1.0
# 118                2.0
# 98                 1.0
# 95                 2.0
# 423                1.0
# 464                1.0
# 11                 1.0
# 638                1.0
# 481                2.0
# 437                1.0
# 568                2.0
# 134                2.0
# 147                1.0
# 631                1.0
# 335                1.0
# 510                2.0
# 196                1.0
# 3                  2.0
# 152                1.0
# 102                1.0
# 659                1.0
# 507                1.0
# 451                2.0
# 630                1.0
# 267                1.0
# 136                2.0
# 532                2.0
# 301                1.0
# 337                2.0
# 193                1.0
# 338                2.0
# 35                 2.0
# 50                 1.0
# 263                1.0
# 470                1.0
# 550                1.0
# 240                1.0
# 681                2.0
# 73                 1.0
# 529                1.0
# 562                1.0
# 490                1.0
# 586                1.0
# 138                1.0

# %%
process_purpose('Personal').tail(50)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                                Make    Engine.Type  Total_Injuries  \
# 299                  FLEETWOOD JACK  Reciprocating             0.0
# 298                           FLEET  Reciprocating             0.0
# 297                  FK LIGHTPLANES  Reciprocating             0.0
# 295                     FIELDS MIKE  Reciprocating             0.0
# 294               FETTERMAN LANNY R  Reciprocating             0.0
# 292                          FERDON  Reciprocating             0.0
# 327               GOLDEN CIRCLE AIR  Reciprocating             0.0
# 291             FARTHING JAMES W II  Reciprocating             0.0
# 290                 FANTASY AIR SRO  Reciprocating             0.0
# 289                     FANTASY AIR  Reciprocating             0.0
# 285   Extra Flugzeugproduktions-und  Reciprocating             0.0
# 275    Eclipse Aviation Corporation      Turbo Fan             0.0
# 274                         Eclipse      Turbo Fan             0.0
# 272               EXTRA FLUGZEUGBAU  Reciprocating             0.0
# 264                         EMBRAER      Turbo Fan             0.0
# 262             EIPPER FORMANCE INC  Reciprocating             0.0
# 257                          Downer  Reciprocating             0.0
# 256     Diamond Aircraft Industries  Reciprocating             0.0
# 253                    De Havilland     Turbo Prop             0.0
# 326                GMK VENTURES LLC  Reciprocating             0.0
# 328           GOLDEN CIRCLE AIR INC  Reciprocating             0.0
# 386                          JABIRU  Reciprocating             0.0
# 365                    Hawker Beech  Reciprocating             0.0
# 385                 J&J Ultralights  Reciprocating             0.0
# 383                   Ison Aircraft  Reciprocating             0.0
# 382                            Icon  Reciprocating             0.0
# 381                      INTERSTATE  Reciprocating             0.0
# 379                      INTERPLANE  Reciprocating             0.0
# 378  INIZIATIVE INDUSTRIALI ITALIAN  Reciprocating             0.0
# 377             INDUS AVIATION INC.  Reciprocating             0.0
# 375                             IAI      Turbo Fan             0.0
# 374                          Howard  Reciprocating             0.0
# 373           Higher Class Aviation  Reciprocating             0.0
# 1                       2021FX3 LLC  Reciprocating             0.0
# 367         Hawker Beechcraft Corp.  Reciprocating             0.0
# 364                HUMMEL / FINBERG  Reciprocating             0.0
# 331                  GRIMES BARRY R  Reciprocating             0.0
# 361                  HOLLEY CAROL L  Reciprocating             0.0
# 360  HIGGINS JOHN H/WILLIAMS JOHN D  Reciprocating             0.0
# 359                          HEMMER  Reciprocating             0.0
# 357   HAWKER BEECHCRAFT CORPORATION     Turbo Prop             0.0
# 356          HAWKER BEECHCRAFT CORP      Turbo Fan             0.0
# 349                      Gulfstream      Turbo Fan             0.0
# 348       Grumman American Aviation  Reciprocating             0.0
# 345                     Great Lakes  Reciprocating             0.0
# 344                    Golden Eagle  Reciprocating             0.0
# 343                   Golden Circle  Reciprocating             0.0
# 341       GULFSTREAM AMERICAN CORP.      Turbo Fan             0.0
# 336     GRUMMAN AMERICAN AVN. CORP.      Turbo Fan             0.0
# 741                    de Havilland  Reciprocating             0.0
#
#      Number.of.Engines
# 299                1.0
# 298                1.0
# 297                1.0
# 295                1.0
# 294                1.0
# 292                1.0
# 327                1.0
# 291                1.0
# 290                1.0
# 289                1.0
# 285                1.0
# 275                2.0
# 274                2.0
# 272                1.0
# 264                2.0
# 262                1.0
# 257                1.0
# 256                1.0
# 253                1.0
# 326                1.0
# 328                1.0
# 386                1.0
# 365                1.0
# 385                1.0
# 383                1.0
# 382                1.0
# 381                1.0
# 379                1.0
# 378                1.0
# 377                1.0
# 375                2.0
# 374                1.0
# 373                1.0
# 1                  1.0
# 367                1.0
# 364                1.0
# 331                1.0
# 361                1.0
# 360                1.0
# 359                1.0
# 357                2.0
# 356                2.0
# 349                2.0
# 348                1.0
# 345                1.0
# 344                1.0
# 343                1.0
# 341                2.0
# 336                2.0
# 741                1.0

# %%
process_purpose('Instructional').head(20)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                          Make    Engine.Type  Total_Injuries  \
# 52                     CESSNA  Reciprocating           227.0
# 162                     PIPER  Reciprocating           150.0
# 42                      BEECH  Reciprocating            44.0
# 169                     Piper  Reciprocating            40.0
# 72                     Cessna  Reciprocating            33.0
# 61         CIRRUS DESIGN CORP  Reciprocating            15.0
# 48                      Beech  Reciprocating            13.0
# 2                     AERONCA  Reciprocating             9.0
# 89   DIAMOND AIRCRAFT IND INC  Reciprocating             8.0
# 200               TAYLORCRAFT  Reciprocating             8.0
# 44                   BELLANCA  Reciprocating             6.0
# 53                     CESSNA     Turbo Prop             5.0
# 165        PIPER AIRCRAFT INC  Reciprocating             4.0
# 86                    DIAMOND  Reciprocating             4.0
# 21         AVIAT AIRCRAFT INC  Reciprocating             4.0
# 112        FLIGHT DESIGN GMBH  Reciprocating             4.0
# 149                    MOONEY  Reciprocating             4.0
# 58                   CHAMPION  Reciprocating             4.0
# 74                     Cirrus  Reciprocating             3.0
# 214                ZENAIR LTD  Reciprocating             3.0
#
#      Number.of.Engines
# 52                 2.0
# 162                2.0
# 42                 2.0
# 169                2.0
# 72                 2.0
# 61                 1.0
# 48                 2.0
# 2                  1.0
# 89                 2.0
# 200                1.0
# 44                 1.0
# 53                 1.0
# 165                2.0
# 86                 1.0
# 21                 1.0
# 112                1.0
# 149                1.0
# 58                 1.0
# 74                 1.0
# 214                1.0

# %%
process_purpose('Instructional').tail(20)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                               Make    Engine.Type  Total_Injuries  \
# 106            Evektor-Aerotechnik  Reciprocating             0.0
# 81                 CubCrafters Inc  Reciprocating             0.0
# 94                         Diamond  Reciprocating             0.0
# 83            Czech Sport AIrcraft  Reciprocating             0.0
# 84                    DE HAVILLAND     Turbo Prop             0.0
# 85                     DEHAVILLAND  Reciprocating             0.0
# 87                DIAMOND AIRCRAFT  Reciprocating             0.0
# 88       DIAMOND AIRCRAFT IND GMBH  Reciprocating             0.0
# 91                    DORNIER GMBH      Turbo Fan             0.0
# 92                         DOUGLAS     Turbo Prop             0.0
# 95     Diamond Aircraft Industries  Reciprocating             0.0
# 105         Evektor Aerotechnik AS  Reciprocating             0.0
# 96   Diamond Aircraft Industry Inc  Reciprocating             0.0
# 97                           EAGLE  Reciprocating             0.0
# 98          ENGINEERING & RESEARCH  Reciprocating             0.0
# 99                         ERCOUPE  Reciprocating             0.0
# 100         EVEKTOR-AEROTECHNIK AS  Reciprocating             0.0
# 103                        Ercoupe  Reciprocating             0.0
# 104            Evektor Aerotechnik  Reciprocating             0.0
# 215                         Zenair  Reciprocating             0.0
#
#      Number.of.Engines
# 106                1.0
# 81                 1.0
# 94                 2.0
# 83                 1.0
# 84                 1.0
# 85                 1.0
# 87                 1.0
# 88                 2.0
# 91                 2.0
# 92                 2.0
# 95                 1.0
# 105                1.0
# 96                 1.0
# 97                 1.0
# 98                 1.0
# 99                 1.0
# 100                1.0
# 103                1.0
# 104                1.0
# 215                1.0

# %%
process_purpose('Business').head(20)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                          Make    Engine.Type  Total_Injuries  \
# 16                     CESSNA  Reciprocating            69.0
# 5                       BEECH  Reciprocating            26.0
# 72                      PIPER  Reciprocating            20.0
# 26                     Cessna  Reciprocating            13.0
# 28                     Cessna      Turbo Jet            10.0
# 21         CIRRUS DESIGN CORP  Reciprocating             9.0
# 12                      Beech  Reciprocating             9.0
# 73                      PIPER     Turbo Prop             7.0
# 82  RAYTHEON AIRCRAFT COMPANY  Reciprocating             6.0
# 89                      SMITH  Reciprocating             6.0
# 93                     Socata     Turbo Prop             5.0
# 18                     CESSNA     Turbo Prop             5.0
# 6                       BEECH     Turbo Prop             5.0
# 88             SIAI MARCHETTI  Reciprocating             4.0
# 77                      Piper  Reciprocating             4.0
# 45                    GRUMMAN     Turbo Prop             4.0
# 97       Textron Aviation Inc      Turbo Fan             3.0
# 17                     CESSNA      Turbo Fan             3.0
# 91                    STINSON  Reciprocating             3.0
# 27                     Cessna      Turbo Fan             3.0
#
#     Number.of.Engines
# 16                2.0
# 5                 2.0
# 72                2.0
# 26                2.0
# 28                2.0
# 21                1.0
# 12                2.0
# 73                2.0
# 82                2.0
# 89                2.0
# 93                1.0
# 18                2.0
# 6                 2.0
# 88                1.0
# 77                2.0
# 45                2.0
# 97                2.0
# 17                2.0
# 91                1.0
# 27                2.0

# %%
process_purpose('Business').tail(20)
# Out:
# <ipython-input-206-1a67705c58bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']
#                               Make    Engine.Type  Total_Injuries  \
# 3               AVIAT AIRCRAFT INC  Reciprocating             0.0
# 33                     DEHAVILLAND  Reciprocating             0.0
# 36                Dassault-Breguet      Turbo Fan             0.0
# 59                     LEARJET INC      Turbo Jet             0.0
# 49     GULFSTREAM AM CORP COMM DIV     Turbo Prop             0.0
# 58                         LEARJET      Turbo Jet             0.0
# 57                         LANCAIR  Reciprocating             0.0
# 56                         Jackson  Reciprocating             0.0
# 55      ISRAEL AIRCRAFT INDUSTRIES      Turbo Fan             0.0
# 53                            ICON  Reciprocating             0.0
# 52               Hawker Beechcraft      Turbo Fan             0.0
# 47                      GULFSTREAM      Turbo Fan             0.0
# 38                     DeHavilland     Turbo Prop             0.0
# 44           FOUND ACFT CANADA INC  Reciprocating             0.0
# 43              FLIGHT DESIGN GMBH  Reciprocating             0.0
# 42    Eclipse Aviation Corporation      Turbo Fan             0.0
# 41  EMBRAER EXECUTIVE AIRCRAFT INC      Turbo Jet             0.0
# 40                         EMBRAER      Turbo Fan             0.0
# 39                         Douglas  Reciprocating             0.0
# 99                          YUNEEC       Electric             0.0
#
#     Number.of.Engines
# 3                 1.0
# 33                1.0
# 36                2.0
# 59                2.0
# 49                2.0
# 58                2.0
# 57                1.0
# 56                1.0
# 55                2.0
# 53                1.0
# 52                2.0
# 47                2.0
# 38                2.0
# 44                1.0
# 43                1.0
# 42                2.0
# 41                2.0
# 40                2.0
# 39                2.0
# 99                1.0

# %% [markdown]
# Data Preparation

# %% [markdown]
# Data Analysis

# %% [markdown]
# Visualization

# %% [markdown]
# Evaluation

# %% [markdown]
# Conclusions
